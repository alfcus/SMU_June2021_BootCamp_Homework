# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import and read the charity_data csv
application_df = pd.read_csv("/content/drive/MyDrive/Colab/Homework/Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique(axis=0)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Determine the number of unique values in each column.
for col in application_df.columns:
  if col not in ["STATUS", "ASK_AMT"]:
    print(col)
    print(len(application_df[col].value_counts()))
    print()
# Out:
# APPLICATION_TYPE
# 17
#
# AFFILIATION
# 6
#
# CLASSIFICATION
# 71
#
# USE_CASE
# 5
#
# ORGANIZATION
# 4
#
# INCOME_AMT
# 9
#
# SPECIAL_CONSIDERATIONS
# 2
#
# IS_SUCCESSFUL
# 2

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.APPLICATION_TYPE.value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
app_vals = application_df.APPLICATION_TYPE.value_counts()

cutoff = 100
application_types_to_replace = list(app_vals[app_vals < cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df.CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C6100        1
# C4120        1
# C1820        1
# C2150        1
# C2600        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df.CLASSIFICATION.value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C0           3
# C2710        3
# C3200        2
# C1256        2
# C1267        2
# C1246        2
# C1234        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_vals = application_df.CLASSIFICATION.value_counts()

cutoff = 150
classifications_to_replace = list(class_vals[class_vals < cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1003
# C7000      777
# C1700      287
# C4000      194
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
application_df["IS_SUCCESSFUL"].value_counts()
# Out:
# 1    18261
# 0    16038
# Name: IS_SUCCESSFUL, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop('IS_SUCCESSFUL', axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=2, activation="relu", input_dim=47))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=3, activation="tanh"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 2)                 96
#
#  dense_10 (Dense)            (None, 3)                 9
#
#  dense_11 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 109
# Trainable params: 109
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6336 - accuracy: 0.6829
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5865 - accuracy: 0.7193
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5814 - accuracy: 0.7213
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7216
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5775 - accuracy: 0.7257
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5760 - accuracy: 0.7268
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7273
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5744 - accuracy: 0.7274
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.7280
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5732 - accuracy: 0.7295
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5725 - accuracy: 0.7294
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5721 - accuracy: 0.7297
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5721 - accuracy: 0.7299
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5719 - accuracy: 0.7301
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5714 - accuracy: 0.7299
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7303
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7297
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5705 - accuracy: 0.7301
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7302
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5705 - accuracy: 0.7305
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7306
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5704 - accuracy: 0.7294
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5705 - accuracy: 0.7303
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5703 - accuracy: 0.7301
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5699 - accuracy: 0.7308
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5697 - accuracy: 0.7300
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5694 - accuracy: 0.7310
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5695 - accuracy: 0.7301
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.